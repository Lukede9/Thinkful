# %%
import pandas as pd
import scrapy
import time
from scrapy.crawler import CrawlerProcess

# %%
class eBaySpider(scrapy.Spider):
    name = "eBaySpider"
    start_urls = ['https://www.ebay-kleinanzeigen.de/s-autos/anzeige:angebote/seite:2/c216']
    
    def parse(self, response):
        urls = []
        for i in range(1, 3):
            urls.append(response.xpath('//*[@id="srchrslt-adtable-topads"]/li[{}]/article/div[2]/h2//a/@href'.format(str(i))).extract())
        for i in range(1, 28):
            urls.append(response.xpath('//*[@id="srchrslt-adtable"]/li[{}]/article/div[2]/h2//a/@href'.format(str(i))).extract())
        
        flat_urls = [item for sublist in urls for item in sublist]
        
        for url in flat_urls:
            url = response.urljoin(url)
            yield scrapy.Request(url=url, callback=self.parse_listing)
     
        next_page_url = response.xpath('//*[@id="srchrslt-pagination"]/div/div[3]/a/@href').extract_first()
        if next_page_url:
            next_page_url = response.urljoin(next_page_url)
            yield scrapy.Request(url=next_page_url, callback=self.parse)
    
    def parse_listing(self, response):
        gte = {"Besch\u00e4digtes Fahrzeug:" : "notRepairedDamage",
                "Marke:" : "brand",
                "Modell:" : "model",
                "Kilometerstand:" : "kilometer",
                'Erstzulassungsjahr:' : "yearOfRegistration",
                "Fahrzeugtyp:" : 'vehicleType',
                "Kraftstoffart:" : 'fuelType',
                "Leistung (PS):" : "powerPS",
                "Getriebe:" : "gearbox",
                "T\u00dcV Jahr:" : "someYearThing",
                "T\u00dcV Monat:": "monthThing",
                "Umweltplakette:" : "environmentalThing",
                "Schadstoffklasse:" : "emissionThing",
                "Au\u00dfenfarbe:": "color",
                "Material Innenausstattung:" : "interiorMaterial",
                "Anzahl Türen:" : "numberOfDoors",
                "Ausstattung:" : 'domesticEquipment',
                "Ort:" : "place",
                "Erstellungsdatum:" : 'creationDate',
                "Anzeigennummer:" : "referenceNumber",
                "Erstzulassungsmonat:": "monthOfRegistration",
              }
        
        for listing in response.xpath('//*[@id="viewad-main"]'):
            vari = {'name' : ''.join(listing.xpath("//*[@id='viewad-title']/text()").extract()).strip(),
                'price' : ''.join(listing.xpath("//*[@id='viewad-price']/text()").extract()).strip()
                  }
        for listing in response.xpath('//*[@id="viewad-details"]/section'):
            able = {gte[''.join(listing.xpath("//dl/dt[{}]/text()".format(i)).extract()).strip()] : ''.join(listing.xpath("//dl/dd[{}]/span/text()".format(i)).extract()).strip()+''.join(listing.xpath("//dl/dd[{}]/span/a/text()".format(i)).extract()).strip() for i in list(range(1,22))}
            
                
                    
        yield {**vari, **able}

# %%
start = time.time()
# Instantiate our crawler.
process = CrawlerProcess({
    'FEED_FORMAT': 'json',
    'FEED_URI': 'used_cars.json',
    'ROBOTSTXT_OBEY': True,
    'LOG_ENABLED': False,
    'AUTOTHROTTLE_ENABLED': True,
    'HTTPCACHE_ENABLED': True
})

# Start the crawler with our spider.
process.crawl(eBaySpider)
process.start()
print(time.time() - start)
# Out:
# 52.41045880317688

# %%
used_cars = pd.read_json('used_cars.json')

# %%
# comparing how these scraped differently and trying to correct it
used_cars
# Out:
#              brand    color creationDate domesticEquipment emissionThing  \
# 0          Porsche     Weiß                                        Euro6
# 1       Volkswagen     Blau                                        Euro2
# 10            3 (Gelb)         Diesel    Manuell            Stoff    312.000
# 11            4 (Grün)         Diesel  Automatik        Vollleder    208.000
# 12            3 (Gelb)         Diesel  Automatik        Vollleder    313.000
# 13            4 (Grün)         Benzin  Automatik            Stoff      4.657
# 14            4 (Grün)         Diesel    Manuell        Vollleder    170.000
# 15            4 (Grün)         Benzin  Automatik            Stoff    175.000
# 16            4 (Grün)         Benzin  Automatik        Vollleder    122.000
# 17            4 (Grün)         Diesel  Automatik        Vollleder    150.000
# 18            4 (Grün)  Autogas (LPG)  Automatik        Vollleder    214.000
# 19            4 (Grün)         Diesel    Manuell            Stoff    200.000
# 20            4 (Grün)         Benzin    Manuell        Vollleder    178.000
# 21            4 (Grün)         Diesel  Automatik        Teilleder    226.000
# 22            4 (Grün)         Benzin  Automatik        Alcantara    198.000
# 23            4 (Grün)         Benzin    Manuell        Teilleder      9.450
# 24            4 (Grün)         Benzin    Manuell        Vollleder    162.000
# 25            4 (Grün)         Benzin    Manuell            Stoff     29.800
# 26            4 (Grün)         Diesel  Automatik            Stoff     59.986
# 27            4 (Grün)         Diesel  Automatik        Vollleder    260.000
# 28            4 (Grün)         Diesel    Manuell            Stoff    232.000
# 29            4 (Grün)         Benzin    Manuell            Stoff    215.730
# ..                 ...            ...        ...              ...        ...
# 226           4 (Grün)         Benzin    Manuell            Stoff     42.529
# 227           4 (Grün)         Benzin    Manuell            Stoff     29.854
# 228           4 (Grün)         Diesel    Manuell            Stoff    162.200
# 229           4 (Grün)         Diesel    Manuell            Stoff     81.000
# 230           4 (Grün)         Benzin    Manuell            Stoff    196.000
# 231           4 (Grün)         Benzin    Manuell            Stoff     50.000
# 232           4 (Grün)         Diesel    Manuell          Velours    239.987
# 233           4 (Grün)         Benzin    Manuell            Stoff    151.000
# 234           4 (Grün)         Diesel  Automatik            Stoff     66.828
# 235           4 (Grün)         Diesel    Manuell            Stoff    161.000
# 236           4 (Grün)         Diesel    Manuell            Stoff    108.000
# 237           4 (Grün)         Benzin    Manuell        Teilleder      7.500
# 238           4 (Grün)         Diesel    Manuell        Alcantara    184.300
# 239           4 (Grün)         Benzin    Manuell        Vollleder     88.208
# 240           4 (Grün)         Benzin    Manuell            Stoff    128.200
# 241           4 (Grün)         Diesel    Manuell        Vollleder    208.000
# 242           4 (Grün)         Diesel  Automatik            Stoff    249.000
# 243           4 (Grün)         Benzin    Manuell            Stoff    149.000
# 244           4 (Grün)         Benzin  Automatik        Vollleder    141.632
# 245           4 (Grün)         Benzin    Manuell            Stoff     90.900
# 246           4 (Grün)         Diesel    Manuell            Stoff    229.000
# 247           4 (Grün)         Benzin  Automatik            Stoff    149.300
# 248           4 (Grün)         Diesel    Manuell            Stoff    192.000
# 249           4 (Grün)         Benzin    Manuell        Teilleder     64.000
# 250           4 (Grün)         Diesel  Automatik        Teilleder    179.000
# 251           4 (Grün)         Benzin    Manuell            Stoff    103.000
# 252           4 (Grün)         Benzin    Manuell            Stoff    234.000
# 253           4 (Grün)         Benzin    Manuell            Stoff    230.100
# 254           4 (Grün)         Benzin    Manuell        Alcantara    177.000
# 255           4 (Grün)         Benzin  Automatik            Stoff    223.000
#
#            ...                                                       name  \
# 0          ...          Porsche 991 Carrera 4S Cabriolet SportChrono S...
# 1          ...                                        Volkswagen Golf 1.6
# 2          ...          Mini Cabrio  Sonderausstattung mit TÜV Leder s...
# 3          ...          Volkswagen Passat CC 2.0 TDI BlueMotion Techno...
# 4          ...          Smart fortwo Coupe Passion/Cool&Audio/JBL/LED/...
# 5          ...          Smart fortwo Coupe Prime/twinamic/Cool&Audio/L...
# 6          ...                               BMW 525xi M Paket XENON NAVI
# 7          ...          Nissan Micra 1.2 edition 25 Jahre 1 Jahr Garan...
# 8          ...          Toyota Yaris Basis, Neue Ganzjahresreifen, Tüv...
# 9          ...                    Opel Meriva 1.8 16V Cosmo mit Gasanlage
# 10         ...          Audi A4 2,5 TDI 6Gang 179Ps Quattro TÜV 12.19 ...
# 11         ...                                   Q7 Audi mit frischen TÜV
# 12         ...              Bmw 525d Automatik Exklusive Fast Voll TAUSCH
# 13         ...          Smart fortwo Coupe Passion/twinamic/Navi/LED/S...
# 14         ...                               Honda Accord Tourer 2.2 CTDI
# 15         ...                              1996 FORD (USA) RANGER PICKUP
# 16         ...                                       Verkauf mein Bmw 320
# 17         ...          Volkswagen Touareg4.2V8R-Line+Exclusive wirkli...
# 18         ...                               Mercedes Benz S 500L 4 matic
# 19         ...          Vw golf 5. 1,9 bls bluemotion 5 gang. Motor ge...
# 20         ...          BMW 320I e36 Limousine (kein 316, 318, 323, 32...
# 21         ...          MERCEDES BENZ E 200 CDI AUTOMATIK AVANTGARDE 2...
# 22         ...          A4 Avant 1.8 TSI S-Line, Vollausstattung schec...
# 23         ...            Hyundai i30 2.0 T-GDI - mit OZ Felgen, H&R etc.
# 24         ...                               BMW 130i M-Paket,M-Performan
# 25         ...                                        Volkswagen UP! Move
# 26         ...          Volkswagen Golf VII Variant 1.6 TDI DSG Navi S...
# 27         ...                                            Audi A6 3.0 TDI
# 28         ...                   VW T5 Top Zustand bis Sonntag reserviert
# 29         ...            Vw jetta 1km bj2006 tüv neu 2.0tfsi 200ps sport
# ..         ...                                                        ...
# 226        ...          Seat Toledo 1.2 TSI Style LED NAVI AAC SHZ PDC...
# 227        ...          Mazda 2 1.5 SKYACTIV-G Center-Line SHZ PDC Blu...
# 228        ...          Mercedes A 180 cdi 162tkm 2 Jahre TÜV und ASU ...
# 229        ...          Seat Altea XL 1.6 TDI CR ECO AAC StartStop PDC...
# 230        ...                                          Seat Leon 1.6 16V
# 231        ...                                Skoda Citigo 1.0 MPI Active
# 232        ...          Volkswagen Passat Variant Comfortline 2.0TDI N...
# 233        ...                                                Skoda fabia
# 234        ...          Opel Astra J 2.0 CDTI Aut. XENON NAVI KAMERA S...
# 235        ...                                         MINI Mini Cooper D
# 236        ...                             Volkswagen T5 California Beach
# 237        ...                          Renault Twingo 1.2 ECO2 Dynamique
# 238        ...             Renault Laguna Grandtour 2.0 dCi FAP Dynamique
# 239        ...          Rover 45 - Benziner - Blaumetallic - Tüv 11/20...
# 240        ...                            Fiat Grande Punto 1.2 8V Actual
# 241        ...           Renault laguna 3 initial(tauchen oder verkaufen)
# 237               Nein            2/3            75      Preis: 6.500 €
# 238               Nein            4/5           150      Preis: 4.790 €
# 239               Nein            4/5           117   Preis: 1.200 € VB
# 240               Nein            2/3            69      Preis: 2.700 €
# 241               Nein            4/5           173   Preis: 4.000 € VB
# 242               Nein            4/5     ,     231          Preis:  VB
# 243               Nein            2/3            75      Preis: 1.550 €
# 244               Nein            2/3           192  Preis: 13.850 € VB
# 245               Nein            2/3            87   Preis: 5.200 € VB
# 246               Nein            2/3     ,     105   Preis: 2.990 € VB
# 247               Nein            4/5           147   Preis: 1.950 € VB
# 248                 Ja            4/5           128     Preis: 925 € VB
# 249               Nein            2/3            69   Preis: 6.900 € VB
# 250               Nein            4/5           190     Preis: 13.449 €
# 251               Nein            4/5            90      Preis: 4.299 €
# 252               Nein            4/5            92     Preis: 690 € VB
# 253               Nein            4/5           150   Preis: 1.800 € VB
# 254               Nein            4/5           250   Preis: 6.000 € VB
# 255               Nein            4/5           136   Preis: 2.900 € VB
#
#     referenceNumber  someYearThing       vehicleType yearOfRegistration
# 0                             2020            Cabrio               2017
# 1                             2020         Limousine               1997
# 2                             2020            Cabrio               2006
# 3                             2020             Coupé               2011
# 4                             2021        Kleinwagen               2018
# 5                             2021        Kleinwagen               2018
# 6                             2019         Limousine               2007
# 7                             2021         Limousine               2009
# 8                             2020        Kleinwagen               2009
# 9                             2019           Van/Bus               2004
# 10                            2019             Kombi               2004
# 11                            2021  SUV/Geländewagen               2007
# 12                            2019         Limousine               2001
# 13                            2021        Kleinwagen               2018
# 14                            2020             Kombi               2005
# 15                            2020  SUV/Geländewagen               1996
# 16                            2020         Limousine               2005
# 17                            2020  SUV/Geländewagen               2012
# 18                            2020         Limousine               2004
# 19                            2019             Kombi               2009
# 20                            2019         Limousine               1995
# 21                            2020         Limousine               2007
# 22                            2020             Kombi               2008
# 23                            2021         Limousine               2018
# 24                            2021         Limousine               2006
# 25                            2020        Kleinwagen               2017
# 26                            2020             Kombi               2015
# 27                            2019         Limousine               2004
# 28                            2019           Van/Bus               2006
# 29                            2021         Limousine               2006
# ..              ...            ...               ...                ...
# 226                           2020         Limousine               2015
# 227                           2020         Limousine               2015
# 228                           2021        Kleinwagen               2005
# 229                           2019           Van/Bus               2012
# 230                           2019         Limousine               2005
# 231                           2020        Kleinwagen               2015
# 232                           2020             Kombi               2007
# 233                           2020        Kleinwagen               2006
# 234                           2019             Kombi               2015
# 235                           2021        Kleinwagen               2008
# 236                           2021           Van/Bus               2014
# 237                           2020        Kleinwagen               2013
# 238                           2020             Kombi               2008
# 239                           2020         Limousine               2001
# 240                           2020        Kleinwagen               2010
# 241                           2020             Kombi               2008
# 242                           2020         Limousine               2010
# 243                           2020        Kleinwagen               2005
# 244                           2020            Cabrio               2006
# 245                           2019        Kleinwagen               2011
# 246                           2020         Limousine               2004
# 247                           2019         Limousine               2002
# 248                           2019           Van/Bus               2003
# 249                           2020            Cabrio               2011
# 250                           2019           Van/Bus               2011
# 251                           2019        Kleinwagen               2007
# 252                           2019             Kombi               1998
# 253                           2019             Kombi               2000
# 254                           2020         Limousine               2003
# 255                           2019         Limousine               1999
#
# [256 rows x 23 columns]
